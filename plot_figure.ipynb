# %%
import numpy as np
import pandas as pd 
import os 
import matplotlib.pyplot as plt
import seaborn as sns 
import glob

# %%
data_path = '../Data_analyst'
os.chdir(data_path)
os.listdir(data_path)
# Out:
# ['.DS_Store', 'Project_0']

# %%
df_global = pd.read_excel('Project_0/results_global_am.xlsx')
df_global.head(10)
# Out:
#    avg_temp  year  avg_temp.1
# 0      8.72  1750         NaN
# 1      7.98  1751         NaN
# 2      5.78  1752         NaN
# 3      8.39  1753         NaN
# 4      8.47  1754         NaN
# 5      8.36  1755         NaN
# 6      8.85  1756         NaN
# 7      9.02  1757         NaN
# 8      6.74  1758         NaN
# 9      7.99  1759    8.034444

# %%
df_global = df_global.dropna(axis=0)
df_global.head()
# Out:
#     avg_temp  year  avg_temp.1
# 9       7.99  1759    8.034444
# 10      7.19  1760    7.953333
# 11      8.77  1761    7.865556
# 12      8.61  1762    8.197778
# 13      7.50  1763    8.222222

# %%
df_hamburg = pd.read_excel('Project_0/results_hamburg_am.xlsx')
df_hamburg.head(10)
# Out:
#    avg_temp  year     city  avg_temp_am
# 0      6.23  1743  Hamburg          NaN
# 1      9.63  1744  Hamburg          NaN
# 2      1.25  1745  Hamburg          NaN
# 3      9.31  1750  Hamburg          NaN
# 4      8.94  1751  Hamburg          NaN
# 5      4.65  1752  Hamburg          NaN
# 6      8.12  1753  Hamburg          NaN
# 7      7.88  1754  Hamburg          NaN
# 8      7.69  1755  Hamburg          NaN
# 9      8.64  1756  Hamburg        7.234

# %%
df_hamburg = df_hamburg.dropna(axis=0)
df_hamburg.head()
# Out:
#     avg_temp  year     city  avg_temp_am
# 9       8.64  1756  Hamburg        7.234
# 10      8.48  1757  Hamburg        7.459
# 11      7.76  1758  Hamburg        7.272
# 12      8.69  1759  Hamburg        8.016
# 13      8.36  1760  Hamburg        7.921

# %%
plt.plot(df_hamburg['year'],df_hamburg['avg_temp_am'],'rs-',label = 'Hamburg')
plt.plot(df_global['year'],df_global['avg_temp.1'],'bs-',label = 'global')
plt.legend(fontsize=20)
plt.title('Temperature variation\nfrom 1750 to 2000',fontsize=20)
plt.xlabel('Year',fontsize=14)
plt.ylabel('Averaged temperature\n(Every 10 Years)',fontsize=20)
plt.yticks(fontsize=20)
plt.xticks(fontsize=20)
# Out:
# (array([1700., 1750., 1800., 1850., 1900., 1950., 2000., 2050.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])
